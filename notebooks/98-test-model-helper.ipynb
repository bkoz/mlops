# %%
import torch
from fc_model import Network, train, validation
from helper import test_network, imshow, view_classify
from torchvision import datasets, transforms
from torch import nn
import time

#
# Program that leverages fc_model and helper libraries.
#

#
# Define a Neural Network
#
model = Network(input_size=28 * 28, output_size=10, hidden_layers=[256, 128, 64], drop_p=0.5)

#
# Define a transform to normalize the input data.
#
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,)),
                              ])
# Download and load the MNIST training data
trainset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the MNIST training data
testset = datasets.FashionMNIST('~/.pytorch/MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# Define the loss
criterion = nn.CrossEntropyLoss()

t0 = time.time()
# Test fc_model's train function.
train(model, trainloader, testloader, criterion, optimizer=None, epochs=5, print_every=64)
print(f'Elapsed training time = {time.time() - t0}')

# Test fc_model's validation function.
test_loss, accuracy = validation(model, testloader, criterion)
print(f'test_loss: {test_loss}, accuracy: {accuracy}')
# Out:
# Epoch: 1/5..  Training Loss: 1.567..  Test Loss: 0.958..  Test Accuracy: 0.552
# Epoch: 1/5..  Training Loss: 1.294..  Test Loss: 0.903..  Test Accuracy: 0.642
# Epoch: 1/5..  Training Loss: 1.299..  Test Loss: 0.881..  Test Accuracy: 0.675
# Epoch: 1/5..  Training Loss: 1.279..  Test Loss: 0.838..  Test Accuracy: 0.676
# Epoch: 1/5..  Training Loss: 1.298..  Test Loss: 0.857..  Test Accuracy: 0.691
# Epoch: 1/5..  Training Loss: 1.275..  Test Loss: 0.874..  Test Accuracy: 0.686
# Epoch: 1/5..  Training Loss: 1.265..  Test Loss: 0.850..  Test Accuracy: 0.665
# Epoch: 1/5..  Training Loss: 1.212..  Test Loss: 0.832..  Test Accuracy: 0.661
# Epoch: 1/5..  Training Loss: 1.238..  Test Loss: 0.830..  Test Accuracy: 0.670
# Epoch: 1/5..  Training Loss: 1.200..  Test Loss: 0.859..  Test Accuracy: 0.682
# Epoch: 1/5..  Training Loss: 1.281..  Test Loss: 0.956..  Test Accuracy: 0.595
# Epoch: 1/5..  Training Loss: 1.266..  Test Loss: 0.869..  Test Accuracy: 0.647
# ...
